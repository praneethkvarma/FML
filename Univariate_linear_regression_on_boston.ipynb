# %% [markdown]
# <a href="https://colab.research.google.com/github/praneethkvarma/FML/blob/main/Univariate_linear_regression_on_boston.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import linear_model

# %%
data = pd.read_csv("/content/boston.csv")
print(data.head())
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
X = data.drop('medv',axis=1).values
y = data['medv'].values
x = X[:,5]#spliting rooms
print(type(x),type(y))
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
x.shape , y.shape
# Out:
# ((506,), (506,))

# %%
x=x.reshape(-1,1)
y=y.reshape(-1,1)
x.shape , y.shape
# Out:
# ((506, 1), (506, 1))

# %%
plt.scatter(x,y)
plt.xlabel("Number of rooms")
plt.ylabel("Value of the house/1000$")
plt.show()

# %%
model = linear_model.LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
y_pred = model.predict(x)
print(f"MAE : {mean_absolute_error(y,y_pred)}")
print(f"MSE : {mean_squared_error(y,y_pred)}")
print(f"RMSE : {mean_squared_error(y,y_pred)**0.5}")
print(f"R2 : {r2_score(y,y_pred)}")
# Out:
# MAE : 4.4477729015322325
# MSE : 43.60055177116956
# RMSE : 6.603071389222561
# R2 : 0.48352545599133423

# %%
prediction_space = np.linspace(min(x),max(x)).reshape(-1,1)

# %%
plt.scatter(x,y,color="blue")
plt.plot(x,y_pred,color="red",linewidth=3)
plt.show()

# %%
plt.scatter(x,y,color="blue")
plt.plot(prediction_space,model.predict(prediction_space),color="green",linewidth=3)
plt.show()
